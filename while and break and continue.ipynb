# %%
i = 0
while i<=10:
    x=0
    while x<i:
        print("swati",end="-")
        x += 1
    print("")
    i += 1
# Out:
# swati-
# swati-swati-
# swati-swati-swati-
# swati-swati-swati-swati-
# swati-swati-swati-swati-swati-
# swati-swati-swati-swati-swati-swati-
# swati-swati-swati-swati-swati-swati-swati-
# swati-swati-swati-swati-swati-swati-swati-swati-
# swati-swati-swati-swati-swati-swati-swati-swati-swati-
# swati-swati-swati-swati-swati-swati-swati-swati-swati-swati-
