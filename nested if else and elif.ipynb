# %%
weight=float(input('Enter weight in kg:'))
height=float(input('Enter height in meter:'))

bmi = round(weight/height ** 2)
if bmi < 18.5:
    print(f"your BMI is {bmi}and you are underweight.")
elif bmi <25:
    print(f"your BMI is{bmi}and you have a normal weight.")
elif bmi <30:
    print(f"your BMI is{bmi}and you have are over weight.")
elif bmi <35:
    print(f"your BMI is{bmi}and you have are Obese.")
else:
    print(f"your BMI is{bmi} and you are clinically Obese.")
# Out:
# Enter weight in kg:45
# Enter height in meter:6
# your BMI is 1and you are underweight.

# %%
weight=float(input('Enter weight in kg:'))
height=float(input('Enter height in meter:'))

bmi = round(weight/height ** 2)
if bmi < 18.5:
    print(f"your BMI is {bmi}and you are underweight.")
elif bmi <25:
    print(f"your BMI is{bmi}and you have a normal weight.")
elif bmi <30:
    print(f"your BMI is{bmi}and you have are over weight.")
elif bmi <35:
    print(f"your BMI is{bmi}and you have are Obese.")
else:
    print(f"your BMI is{bmi} and you are clinically Obese.")
# Out:
# Enter weight in kg:56
# Enter height in meter:1.9
# your BMI is 16and you are underweight.

# %%
year = int(input("which year you want to check"))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap year")
        else:
            print("Not leap year")
    else:
        print("Leap year")
else:
    print("Not leap year")
# Out:
# which year you want to check2004
# Leap year
